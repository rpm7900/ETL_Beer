# %%
import requests
import pandas as pd
from pprint import pprint
from flask import jsonify

# %%
url = "https://maps.googleapis.com/maps/api/geocode/json?address="
APIK = "AIzaSyCDoYS5b5YZEuD4gAHbjpDXhpLrxlz-MRY"

request_url = f"{url}{address}&key={APIK}"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fe9edfda6067> in <module>
#       2 APIK = "AIzaSyCDoYS5b5YZEuD4gAHbjpDXhpLrxlz-MRY"
#       3
# ----> 4 request_url = f"{url}{address}&key={APIK}"
#
# NameError: name 'address' is not defined

# %%
data_file = "ETL_Beer/CSV/breweries_and_brew_pubs_in_the_usa.csv"

data_df = pd.read_csv(data_file, encoding="ISO-8859-1")

# %%
data_df.head()
# Out:
#                      id                              address  \
# 0  AVweN1T_ByjofQCxwSPL                          Syr Airport
# 1  AVwdkF9ZIN2L1WUfxDfw  1320 N Doctor Martin Luther King Dr
# 2  AVwdlPkf_7pvs4fz7TMr                           608 4th St
# 3  AVwcucY0kufWRAb5yWbU                        1103 Mills St
# 4  AVweCkd5kufWRAb5_eaI                   130 W Riverside Dr
#
#                                       categories            city country  \
# 0                                        Brewery        Syracuse      US
# 1             Office and Cafeteria Brewer's Hill       Milwaukee      US
# 2                        Brewery Downtown Clovis          Clovis      US
# 3                          breweries & brew pubs     Black Earth      US
# 4  Brewery and Gastropub Downtown Jeffersonville  Jeffersonville      US
#
#                                                hours  \
# 0                                                NaN
# ...

# %%
zip_lookup = data_df[data_df['postalCode'].isnull()]
#create a df of rows missing postal code

already_done = data_df[~data_df['postalCode'].isnull()]
#create a df of rows that already have the postal code by removing previous df from original df

#cobbles together and runs API request for zip code from input address
def getTheZip(raw_address):
    address = raw_address.replace(" ", "+")
    url = "https://maps.googleapis.com/maps/api/geocode/json?address="
    APIK = "AIzaSyCDoYS5b5YZEuD4gAHbjpDXhpLrxlz-MRY"
    request_url = f"{url}{address}&key={APIK}"
    response = requests.request("GET", request_url)
    zip_code = None
    try:
        zip_code = response.json()['results'][0]['address_components'][7]['short_name']
    except (IndexError):
        print(raw_address)
    return zip_code

zip_lookup['postalCode'] = zip_lookup['address'].apply(lambda x: getTheZip(x))
#applies 'getTheZip' function (which still needs to be written) to every row in zip_lookup df
#getTheZip should look like:
#def getTheZip(raw_address):
#   (API request routine from requester_tester.ipynb)
# Out:
# Av Brasil 3290
# Av Silvio Carlos Viana Barraca 27
# 1750 Bloomsbury Ave
# Av Manoel Ribas 6995
# Terceira Avenida 1840
# Lot 3 Hemsley Rd
# Mile 17 Klondike Hwy
# Continente Park Shopping
# Parque Vila Germnica
# 60 Hamersley St
# 29 & 113
# R Mxico 291
# 4561 Market St A
# 1920 East University Drive #104
# 7955 Sliverton Ave #1201
# 204 East Enterprise Street
# R Mateus Leme 950
# 1 Sausalito
# 3770 South Las Vegas Boulevard
# 601699 22nd St
# 2470 Bates Avenue # C
# 1641 S. Stapley Drive
# 980 Park Center Drive
# Eldorado National Forest
# 321 Firehouse Alley
# 415 Grand Avenue
# Chicago
# 28822 Old Town Front St. #108
# Julian Rd
# 10990 Industrial Way
# 2501 Monarch St
# 538 Falmouth Road
# La Costa Meadows Drive
# Rua Desembargador Pedro Silva 2406
# Gate A63
# 241 U 1 Camboon Rd
# Rua Ibipor 884
# Julian Rd
# 302 East Broadway
# Columbus St
# 64 South Tce
# Las Vegas
# 1641 S. Stapley Drive
# 1404 4th Street
# 1441 L St
# 15378 Avenue of Science #222
# 5788 2nd Street
# ...

# %%
zip_lookup.head()
# Out:
#                       id                            address  \
# 0   AVweN1T_ByjofQCxwSPL                        Syr Airport
# 23  AVwcj_oMIN2L1WUfmWSo                     Av Brasil 3290
# 63  AVwcx9j8_7pvs4fzy5NX  Av Silvio Carlos Viana Barraca 27
# 70  AVweZ_maIN2L1WUf4oIG                1750 Bloomsbury Ave
# 78  AVwdNGVQIN2L1WUftUN9               Av Manoel Ribas 6995
#
#                        categories              city country  \
# 0                         Brewery          Syracuse      US
# 23          Gastropub and Brewery  Balnerio Cambori      US
# 63  Bar, Beer Garden, and Brewery             Macei      US
# 70         Breweries,Food & Drink             Ocean      US
# 78        Brewery and Beer Garden          Curitiba      US
#
#                                                 hours  \
# 0                                                 NaN
# 23  [{"day":"Sat","hour":"10:00 AM - Midnight"},{"...
# 63  [{"day":"Mon - Sun","hour":"10:00 AM - Midnigh...
# ...

# %%
all_done = pd.concat([zip_lookup, already_done])
all_done.head()
# Out:
#                       id                            address  \
# 0   AVweN1T_ByjofQCxwSPL                        Syr Airport
# 23  AVwcj_oMIN2L1WUfmWSo                     Av Brasil 3290
# 63  AVwcx9j8_7pvs4fzy5NX  Av Silvio Carlos Viana Barraca 27
# 70  AVweZ_maIN2L1WUf4oIG                1750 Bloomsbury Ave
# 78  AVwdNGVQIN2L1WUftUN9               Av Manoel Ribas 6995
#
#                        categories              city country  \
# 0                         Brewery          Syracuse      US
# 23          Gastropub and Brewery  Balnerio Cambori      US
# 63  Bar, Beer Garden, and Brewery             Macei      US
# 70         Breweries,Food & Drink             Ocean      US
# 78        Brewery and Beer Garden          Curitiba      US
#
#                                                 hours  \
# 0                                                 NaN
# 23  [{"day":"Sat","hour":"10:00 AM - Midnight"},{"...
# 63  [{"day":"Mon - Sun","hour":"10:00 AM - Midnigh...
# ...

# %%
all_done.to_csv("ETL_Beer/CSV/clean_breweries_and_brewpubs_in_the_usa.csv")
